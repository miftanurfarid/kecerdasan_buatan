# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Let be a function $f$ from $\mathbb{R}^2$ into $\mathbb{R}$. For any couple $(x, y)$ in $\mathbb{R}^2$ :
#
# $$f(x, y) = 2x^2 — xy + 2y^2$$

# %%
def f(x, y):
    return 2*x**2 - x*y + 2*y**2

# %%
x = np.linspace(-100, 100, 100)
y = np.linspace(-200, 200, 200)

# %%
X, Y = np.meshgrid(x, y)
Z = f(X,Y)

# %%
# We define the size of the figure
fig1 = plt.figure(figsize = (10,7))
ax1 = plt.axes(projection='3d')
ax1.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='jet', edgecolor='none')
# We caption the figure and set a size with fontsize
ax1.set_title("Surface", fontsize = 13)
ax1.set_xlabel('x', fontsize = 11)
ax1.set_ylabel('y', fontsize = 11)
ax1.set_zlabel('Z', fontsize = 10)
# Out:
# Text(0.5, 0, 'Z')

# %%
C = plt.contour(X,Y,Z,10)
plt.xlabel('x')
plt.ylabel('y')
plt.clabel(C, inline=1, fontsize=8)
plt.show()

# %%
def f2(x, y):
    return 3*x**2 - 2*x*y + 3*y**2 - x - y

# %%
x2 = np.linspace(-10, 10, 200)
y2 = np.linspace(-10, 10, 200)

# %%
X2, Y2 = np.meshgrid(x2, y2)
Z2 = f(X2,Y2)

# %%
plt.figure(figsize=(20,12))
C = plt.contour(X2,Y2,Z2,30)
plt.xlabel('x')
plt.ylabel('y')
#plt.clabel(C)
plt.grid()
plt.show()
